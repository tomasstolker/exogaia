# %% [markdown]
# # Completeness map

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from exogaia.data import EpochAstrometry
from exogaia.limits import CompletenessMap

# %%
np.random.seed(42)

# %%
source_id = 6199395656645840384  # HD 135344 A

# %%
primary_mass = (2.2, 0.1)  # (Msun)

# %%
cmap = CompletenessMap(source_id=source_id, primary_mass=primary_mass, gaia_release='DR5')
# Out:
# ----------------
# Epoch astrometry
# ----------------
#
# Gaia release: DR5
# Reference epoch: 2020.0
#
# Primary mass (Msun): 2.20 +/- 0.10
#
# ---------------
# Querying source
# ---------------
#
# Gaia release: DR3
# Source ID: 6199395656645840384
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
# RA = 228.954 deg +/- 0.038 mas
# Dec = -37.149 deg +/- 0.026 mas
# Parallax = 7.411 +/- 0.040 mas
# Proper motion in RA = -18.738 +/- 0.051 mas/yr
# Proper motion in Dec = -24.008 +/- 0.035 mas/yr
# G-band magnitude = 7.748
# Pseudocolor = 1.73 um-1
#
# UWE = 1.96
# RUWE = 0.95
# Astrometric excess noise (mas) = 0.2075 +/- 0.0103
# Non single star = 0

# %%
fig = cmap.calc_completeness(
    n_sigma=3,
    n_samples=30,
    mass_points=np.linspace(0.0001, 0.02, 30),
    filter_sigma=1.0,
    plot_file='cmap.png',
)
# Out:
# ----------------
# Completeness map
# ----------------
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
fig.axes[0].plot(20., 10., 'X', ms=8., mec='white', mfc='tomato')
fig.axes[0].text(20., 8., 'HD 135344 Ab', fontsize=10., color='tomato', va='top', ha='center')
fig.savefig('cmap.png')
fig
